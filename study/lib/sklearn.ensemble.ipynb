# %% [markdown]
# Scikit-learn 的集成学习方法，如随机森林。

# %%
import sklearn.ensemble
print(f'sklearn.ensemble version: {sklearn.ensemble.__version__ if hasattr(sklearn.ensemble, "__version__") else "N/A"}')

# %%
help(sklearn.ensemble)

# %%
dir(sklearn.ensemble)

# %% [markdown]
# ### Help for `RandomForestRegressor`

# %%
help(sklearn.ensemble.RandomForestRegressor)

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=10)
print(model)
