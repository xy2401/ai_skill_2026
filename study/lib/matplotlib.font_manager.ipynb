# %% [markdown]
# matplotlib.font_manager 用于查找和管理字体。

# %%
import matplotlib.font_manager
print(f'matplotlib.font_manager version: {matplotlib.font_manager.__version__ if hasattr(matplotlib.font_manager, "__version__") else "N/A"}')

# %%
help(matplotlib.font_manager)

# %%
dir(matplotlib.font_manager)

# %% [markdown]
# ### Help for `FontProperties`

# %%
help(matplotlib.font_manager.FontProperties)

# %%
from matplotlib.font_manager import FontProperties
fp = FontProperties()
print(f'Default font family: {fp.get_family()}')
