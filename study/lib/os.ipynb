# %% [markdown]
# os 模块提供了各种与操作系统交互的功能。

# %%
import os
print(f'os version: {os.__version__ if hasattr(os, "__version__") else "N/A"}')

# %%
help(os)

# %%
dir(os)

# %% [markdown]
# ### Help for `listdir`

# %%
help(os.listdir)

# %%
import os
print(f'Files in current directory: {os.listdir(".")[:5]}') # Show first 5

# %% [markdown]
# ### Help for `makedirs`

# %%
help(os.makedirs)

# %%
import os
try:
    os.makedirs('test_dir_example', exist_ok=True)
    print('Directory created')
    os.removedirs('test_dir_example')
    print('Directory removed')
except Exception as e:
    print(e)
