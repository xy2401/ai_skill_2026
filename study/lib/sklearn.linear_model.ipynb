# %% [markdown]
# Scikit-learn 的线性模型。

# %%
import sklearn.linear_model
print(f'sklearn.linear_model version: {sklearn.linear_model.__version__ if hasattr(sklearn.linear_model, "__version__") else "N/A"}')

# %%
help(sklearn.linear_model)

# %%
dir(sklearn.linear_model)

# %% [markdown]
# ### Help for `LinearRegression`

# %%
help(sklearn.linear_model.LinearRegression)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
print(model)
