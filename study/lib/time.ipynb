# %% [markdown]
# time 模块提供了处理时间的各种函数。

# %%
import time
print(f'time version: {time.__version__ if hasattr(time, "__version__") else "N/A"}')

# %%
help(time)

# %%
dir(time)

# %% [markdown]
# ### Help for `time`

# %%
help(time.time)

# %%
import time
print(f'Current timestamp: {time.time()}')
