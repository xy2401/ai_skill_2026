# %% [markdown]
# Scikit-learn 的流水线工具。

# %%
import sklearn.pipeline
print(f'sklearn.pipeline version: {sklearn.pipeline.__version__ if hasattr(sklearn.pipeline, "__version__") else "N/A"}')

# %%
help(sklearn.pipeline)

# %%
dir(sklearn.pipeline)

# %% [markdown]
# ### Help for `Pipeline`

# %%
help(sklearn.pipeline.Pipeline)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
estimators = [('scaler', StandardScaler()), ('clf', LinearRegression())]
pipe = Pipeline(estimators)
print(pipe)
