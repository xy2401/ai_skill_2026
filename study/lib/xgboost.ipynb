# %% [markdown]
# XGBoost 是一个优化的分布式梯度增强库。

# %%
import xgboost
print(f'xgboost version: {xgboost.__version__ if hasattr(xgboost, "__version__") else "N/A"}')

# %%
help(xgboost)

# %%
dir(xgboost)

# %% [markdown]
# ### Help for `XGBRegressor`

# %%
help(xgboost.XGBRegressor)

# %%
import xgboost as xgb
model = xgb.XGBRegressor()
print(model)
