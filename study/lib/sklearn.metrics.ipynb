# %% [markdown]
# Scikit-learn 的性能评估指标。

# %%
import sklearn.metrics
print(f'sklearn.metrics version: {sklearn.metrics.__version__ if hasattr(sklearn.metrics, "__version__") else "N/A"}')

# %%
help(sklearn.metrics)

# %%
dir(sklearn.metrics)

# %% [markdown]
# ### Help for `mean_absolute_error`

# %%
help(sklearn.metrics.mean_absolute_error)

# %%
from sklearn.metrics import mean_absolute_error
y_true = [3, -0.5, 2, 7]
y_pred = [2.5, 0.0, 2, 8]
print(f'MAE: {mean_absolute_error(y_true, y_pred)}')

# %% [markdown]
# ### Help for `mean_squared_error`

# %%
help(sklearn.metrics.mean_squared_error)

# %%
from sklearn.metrics import mean_squared_error
y_true = [3, -0.5, 2, 7]
y_pred = [2.5, 0.0, 2, 8]
print(f'MSE: {mean_squared_error(y_true, y_pred)}')

# %% [markdown]
# ### Help for `r2_score`

# %%
help(sklearn.metrics.r2_score)

# %%
from sklearn.metrics import r2_score
y_true = [3, -0.5, 2, 7]
y_pred = [2.5, 0.0, 2, 8]
print(f'R2: {r2_score(y_true, y_pred)}')
