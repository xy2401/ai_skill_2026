# %% [markdown]
# ONNX Runtime 是一个高性能的推理引擎，用于各种框架生成的 ONNX 模型。

# %%
import onnxruntime
print(f'onnxruntime version: {onnxruntime.__version__ if hasattr(onnxruntime, "__version__") else "N/A"}')

# %%
help(onnxruntime)

# %%
dir(onnxruntime)

# %% [markdown]
# ### Help for `InferenceSession`

# %%
help(onnxruntime.InferenceSession)

# %%
print('Example: session = onnxruntime.InferenceSession("model.onnx")')
print('Requires a valid .onnx file to instantiate.')
