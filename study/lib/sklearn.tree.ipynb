# %% [markdown]
# Scikit-learn 的决策树模型。

# %%
import sklearn.tree
print(f'sklearn.tree version: {sklearn.tree.__version__ if hasattr(sklearn.tree, "__version__") else "N/A"}')

# %%
help(sklearn.tree)

# %%
dir(sklearn.tree)

# %% [markdown]
# ### Help for `DecisionTreeRegressor`

# %%
help(sklearn.tree.DecisionTreeRegressor)

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
print(model)
