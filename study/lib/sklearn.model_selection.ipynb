# %% [markdown]
# Scikit-learn 的模型选择工具，如交叉验证。

# %%
import sklearn.model_selection
print(f'sklearn.model_selection version: {sklearn.model_selection.__version__ if hasattr(sklearn.model_selection, "__version__") else "N/A"}')

# %%
help(sklearn.model_selection)

# %%
dir(sklearn.model_selection)

# %% [markdown]
# ### Help for `train_test_split`

# %%
help(sklearn.model_selection.train_test_split)

# %%
from sklearn.model_selection import train_test_split
import numpy as np
X = np.arange(10).reshape((5, 2))
y = range(5)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
print(f'Train size: {len(X_train)}, Test size: {len(X_test)}')
