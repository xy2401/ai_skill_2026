# %% [markdown]
# datetime 模块提供了处理日期和时间的类。

# %%
import datetime
print(f'datetime version: {datetime.__version__ if hasattr(datetime, "__version__") else "N/A"}')

# %%
help(datetime)

# %%
dir(datetime)

# %% [markdown]
# ### Help for `datetime`

# %%
help(datetime.datetime)

# %%
print(f'Current time: {datetime.datetime.now()}')
