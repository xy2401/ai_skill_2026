# %% [markdown]
# pickle 模块实现了对 Python 对象结构的二进制序列化和反序列化。

# %%
import pickle
print(f'pickle version: {pickle.__version__ if hasattr(pickle, "__version__") else "N/A"}')

# %%
help(pickle)

# %%
dir(pickle)

# %% [markdown]
# ### Help for `dump`

# %%
help(pickle.dump)

# %%
import pickle
import os
data = [1, 2, 3]
with open('test.pkl', 'wb') as f:
    pickle.dump(data, f)
print('Data pickled to test.pkl')
if os.path.exists('test.pkl'): os.remove('test.pkl')
