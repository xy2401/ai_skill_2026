# %% [markdown]
# 提供处理目标检测框的工具函数。

# %%
import vision.utils.box_utils_numpy
print(f'vision.utils.box_utils_numpy version: {vision.utils.box_utils_numpy.__version__ if hasattr(vision.utils.box_utils_numpy, "__version__") else "N/A"}')

# %%
help(vision.utils.box_utils_numpy)

# %%
dir(vision.utils.box_utils_numpy)

# %% [markdown]
# ### Help for `hard_nms`

# %%
help(vision.utils.box_utils_numpy.hard_nms)

# %%
import numpy as np
from vision.utils.box_utils_numpy import hard_nms
boxes = np.array([[10, 10, 50, 50], [15, 15, 55, 55]], dtype=np.float32)
scores = np.array([0.9, 0.8], dtype=np.float32)
indices = hard_nms(boxes, scores, iou_threshold=0.5, top_k=10)
print(f'Selected indices: {indices}')
