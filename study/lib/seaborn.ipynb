# %% [markdown]
# Seaborn 是一个基于 Matplotlib 的 Python 数据可视化库。

# %%
import seaborn
print(f'seaborn version: {seaborn.__version__ if hasattr(seaborn, "__version__") else "N/A"}')

# %%
help(seaborn)

# %%
dir(seaborn)

# %% [markdown]
# ### Help for `boxplot`

# %%
help(seaborn.boxplot)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data = [1, 2, 2, 3, 4, 10]
sns.boxplot(x=data)
# plt.show()
print('Boxplot created')
