# %% [markdown]
# joblib 是一个用于在 Python 中提供轻量级流水线的库。

# %%
import joblib
print(f'joblib version: {joblib.__version__ if hasattr(joblib, "__version__") else "N/A"}')

# %%
help(joblib)

# %%
dir(joblib)

# %% [markdown]
# ### Help for `dump`

# %%
help(joblib.dump)

# %%
import joblib
import os
data = {'key': 'value'}
joblib.dump(data, 'test.joblib')
print('Dumped data to test.joblib')
if os.path.exists('test.joblib'): os.remove('test.joblib')
