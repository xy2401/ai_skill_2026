# %%
import pandas as pd
# 正确加载数据集   2分
fdata=__________

# 显示前5行   2分
print(__________)

# 查看数据总体形状(shape)  2分
print(__________)

# 查看数据的描述信息    2分
print(__________)

# %%
# 增加一列“人均消费”    2分
fdata['人均消费']=round(__________,2)
print(fdata.head())

# %%
# 计算小费与总金额的协方差  2分
fdata['消费总额'].__________

# 计算男性、女性的小费平均值  2分    
fdata.__________['小费'].__________()
