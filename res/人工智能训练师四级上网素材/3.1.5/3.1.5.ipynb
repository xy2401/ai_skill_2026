# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 设置中文字体
plt.rcParams['font.sans-serif'] = ['SimHei']  # 使用黑体
plt.rcParams['axes.unicode_minus'] = False  # 解决负号显示问题

# 加载数据集
data = _____________
# 筛选“电影代码”为“33”的数据
movie_33_data = data[_____________]

# 输出头部信息
print(_____________)

# 按照“电影院代码”分组，计算平均“总售票金额”和平均“售票数”
avg_data = _____________("电影院代码")._____________({"总售票金额": "mean", "售票数": "mean"})

# 按照平均“总售票金额”从高到低排序
sorted_avg_data = avg_data.sort_values(_____________, _____________)

# 输出前15条记录
print(_____________)

# 计算“总售票金额”最高的电影院代码
max_revenue_cinema_code = _____________

# 筛选出该电影院的数据
max_revenue_cinema_data = data[_____________]

# 按照“开场时间”分组，计算总售票金额
opening_time_revenue = _____________("开场时间")_____________.sum()
print(opening_time_revenue)
# 绘制柱状图
plt.bar(_____________, _____________)
plt.xlabel("开场时间")
plt.ylabel("总售票金额")
plt.title(f"{max_revenue_cinema_code}电影院不同开场时间的总售票金额分布")
plt.xticks(rotation=45)
plt.show()
