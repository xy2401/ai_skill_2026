# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 设置中文字体
plt.rcParams['font.sans-serif'] = ['SimHei']  # 使用黑体
plt.rcParams['axes.unicode_minus'] = False  # 解决负号显示问题

# 1. 加载数据集并输出“行政区”字段为“浦东新区”的数据头部信息
data = _________
pudong_data = data[data['行政区'] == '浦东新区']
print(_________)


# 2. 计算每个行政区的平均“口味”、“环境”和“服务”评分，并按照综合评分从高到低排序
data = _________ # 不包含“未知”行政区
data['综合评分'] = _________(axis=1)
avg_scores_by_district = _________[['口味', '环境', '服务', '综合评分']]._________(by='综合评分', ascending=False)
print(avg_scores_by_district)

highest_score_district = _________
#print(highest_score_district)
highest_score_district_data = _________
#print(highest_score_district_data)
# 按类别分组，计算人均消费的平均值
avg_consumption_by_category = _________['人均消费']._________(ascending=False)

# 取前15个类别
top_15_categories = _________

plt.figure(figsize=(12, 6))
top_15_categories.plot(kind='bar')
plt.xlabel('类别')
plt.ylabel('人均消费平均值')
plt.title(f'{highest_score_district}人均消费最高的前15个类别')
plt.xticks(rotation=45)
plt.show()
