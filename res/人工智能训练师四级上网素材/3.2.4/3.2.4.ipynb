# %%
import pandas as pd
from datetime import datetime
# 加载数据集         2分
data = __________

#  显示前5行数据     2分
print(__________)

# %%
# 删除领券和消费时间中包含空值的行  2分
data.dropna(subset=[__________, __________], inplace=True)
print(data)

# 将日期数据标准化为：年-月-日     2分
data['领券日期'] = __________(__________, format='%Y%m%d')
data['消费日期'] = __________(__________, format='%Y%m%d')

# 移除消费日期早于领券日期的记录     2分
data = data[__________]
print(data.head())
  
# 增加新特征列“领券到消费天数”    2分
data['领券到消费天数'] = (__________).dt.days  #领券到消费的时间差
print(data.head())

# %%
# 用户领取优惠券到消费的最常见消费间隔
most_common_interval = data['领券到消费天数'].mode()[0]
print(f"最常见消费间隔天数: {most_common_interval}")
