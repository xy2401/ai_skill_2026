# %%
import pandas as pd
# 加载数据     2分
data = __________

# 输出数据前5行     2分
print("前五行数据：")
print(__________)
 
# 描述性统计分析     2分
print("基本统计摘要：")
print(__________)

# %%
# 绘制工作年限与薪资的散点图    2分
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))
plt.scatter(__________, __________, color='blue', label='Data points')
plt.title('Relationship between Years of Experience and Salary')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
# 线性回归建模        2分
from sklearn.linear_model import LinearRegression
X = data[['__________']]  # 特征：员工工作年限
y = data['__________']  # 目标变量：薪资
model = LinearRegression() # 创建线性回归模型
model.fit(X, y)  # 拟合模型
# 输出模型的系数和截距        2分
print("系数:", __________)
print("截距:", __________)

# %%
# 预测薪资     2分
new_experience = pd.DataFrame({'YearsExperience': [7]})
predicted_salary = __________(__________) # 使用已经拟合好的模型进行预测
print("预测的薪资:", predicted_salary[0]) # 打印预测的薪资
