# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 设置中文字体
plt.rcParams['font.sans-serif'] = ['SimHei']  # 使用黑体
plt.rcParams['axes.unicode_minus'] = False  # 解决负号显示问题

# 1. 加载数据集并输出头部信息
data = ______________
print(______________)

# 2. 计算2009年1-11月份的每月的平均压力差，并按照平均压力差从大到小排序
data['日期'] = ______________
data_2009 = data[______________]
monthly_pressure_diff = ______________(ascending=False)
print(monthly_pressure_diff)

# 3. 给出2009年压力差平均值最大的月份，并展示该月份每天的气压差折线图
max_pressure_diff_month = ______________

data_month = data_2009[______________]
data_month = ______________(by='日期')

plt.figure(figsize=(12, 6)) # 设置图形的宽度和高度
______________(______________, marker='o', linestyle='-', linewidth=2) # 绘制折线图并添加数据点
plt.scatter(data_month['日期'], data_month['压力差']) # 添加数据点
plt.xlabel('日期')
plt.ylabel('压力差')
plt.title(f'{max_pressure_diff_month}月份每天的压力差')
plt.grid(True) # 添加网格
______________ # 显示折线图
