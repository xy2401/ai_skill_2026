# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 设置中文字体
plt.rcParams['font.sans-serif'] = ['SimHei']  # 使用黑体
plt.rcParams['axes.unicode_minus'] = False  # 解决负号显示问题

# 加载数据集
data = ______________

# 打印数据集的前几行
print(______________)

# 统计大类名称个数
unique_categories_count = ______________
print(f"大类名称个数: {unique_categories_count}")

# 计算不同大类名称下的总销售金额
category_sales_sum = ______________

# 按照总销售金额从大到小排序
sorted_category_sales = ______________
print(sorted_category_sales)

# 选择销售金额最大的大类名称
max_sales_category = ______________

# 筛选出该大类下的数据
sub_data = data[data["大类名称"] == max_sales_category]

# 计算该大类下各小类的销售总金额
sub_category_sales_sum = ______________.sum()

# 选择销售总金额最大的前15个小类
top_15_sub_categories = ______________

# 绘制柱状图
plt.figure(figsize=(12, 6))
______________  # 绘制柱状图
plt.title(f"{max_sales_category} 下销售总金额最大的前15个小类分布")
plt.xlabel("小类名称")
plt.ylabel("销售金额")
plt.xticks(rotation=45)
plt.tight_layout()  # 自动调整子图参数，使之填充整个图像区域
plt.show()
